# %%
import pyaudio
import numpy as np

# %%
audio = pyaudio.PyAudio()

for index in range(audio.get_device_count()):
    desc = audio.get_device_info_by_index(index)
    print("DEVICE: {device}, INDEX: {index}, RATE: {rate} ".format(
        device=desc["name"], index=index, rate=int(desc["defaultSampleRate"])))
# Out:
# DEVICE: Microsoft 사운드 매퍼 - Output, INDEX: 0, RATE: 44100
# DEVICE: LG HDR 4K(NVIDIA High Definitio, INDEX: 1, RATE: 44100
# DEVICE: 주 사운드 드라이버, INDEX: 2, RATE: 44100
# DEVICE: LG HDR 4K(NVIDIA High Definition Audio), INDEX: 3, RATE: 44100
# DEVICE: LG HDR 4K(NVIDIA High Definition Audio), INDEX: 4, RATE: 48000
# DEVICE: 마이크 (Realtek HD Audio Mic input), INDEX: 5, RATE: 44100
# DEVICE: 라인 입력 (Realtek HD Audio Line input), INDEX: 6, RATE: 44100
# DEVICE: 스테레오 믹스 (Realtek HD Audio Stereo input), INDEX: 7, RATE: 44100
# DEVICE: Headphones (Realtek HD Audio 2nd output), INDEX: 8, RATE: 44100
# DEVICE: Output (NVIDIA High Definition Audio), INDEX: 9, RATE: 48000

# %%
CHUNK = 160       
FORMAT = pyaudio.paInt16  
CHANNELS = 1          
RATE = 16000

# %%
from playsound import playsound

# 오디오 파일 경로
audio_file = "C:\\Users\\ipl1\\Desktop\\IPL\\세미나(25하계)\\data\\sound\\audio\\audio\\16000\\1-137-A-32.wav"

# 오디오 재생
ipd.Audio(audio_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
